# %% [markdown]
# ### Visualizing personal graphs

# %% [markdown]
# getting data from json files:

# %% [markdown]
# ## prepare data

# %%
import json
import networkx as nx

# Load the json files

#retrieve: relationship and relevance score 
with open('RM_user1.json', 'r') as f:
    RM_user1_data = json.load(f)

# retrieve: photo_file_name, who and when
with open('imozuke-user1.json', 'r') as f:
    imozuke_user1_data = json.load(f)
    
# read the files to structure the network

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Example:
true_labels = [9,8,14,4, 5,11, 15, 19, 3, 17, 16, 18, 6, 10, 13, 7, 12, 1, 2,
20,
21]

predicted = [8, 9, 18, 21, 7, 20, 10, 3, 15, 19,
             1, 17, 16, 11, 13, 12, 14, 4, 2,5,6]


cm = confusion_matrix(true_labels, predicted, labels=range(1, 20))

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=range(1, 20), yticklabels=range(1, 20))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Photo Recommendation Confusion Matrix')
plt.show()

# %% [markdown]
# ### Example

# %%
import networkx as nx
import matplotlib.pyplot as plt

H = nx.DiGraph()

# Adding nodes
H.add_nodes_from([
    (0, {"color": "blue", "size": 250}),
    (1, {"color": "yellow", "size": 400}),
    (2, {"color": "orange", "size": 150}),
    (3, {"color": "red", "size": 600}),
])

# Adding edges with weights
H.add_edges_from([
    (0, 1, {'weight': 5}),
    (1, 2, {'weight': 3}),
    (1, 0, {'weight': 2}),
    (1, 3, {'weight': 7}),
    (2, 3, {'weight': 4}),
    (3, 0, {'weight': 6}),
])

# Extracting node attributes
node_colors = list(nx.get_node_attributes(H, "color").values())
node_sizes = list(nx.get_node_attributes(H, "size").values())

# Extracting edge weights for labeling
edge_labels = nx.get_edge_attributes(H, 'weight')

# Plotting the graph
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(H, k=0.8)

nx.draw(H, pos, with_labels=True, node_color=node_colors, node_size=node_sizes)
nx.draw_networkx_edge_labels(H, pos, edge_labels=edge_labels)

plt.show()

# %% [markdown]
# ### Soon's graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

Soons_graph = nx.DiGraph()

user_color = "pink"
fam_color = "orange"
photo_color = "yellow"
defsize = 500

family_mem = ["Soon", "Father", "Mother", "Brother1", "Brother2", "Maternal grandpa", "Cousin", "Sister-In-Law"]
photo_list = [f"photo{i}.png" for i in range(1, 22)]

# Adding nodes
for name in family_mem:
    Soons_graph.add_node(name, color=user_color if name == "Soon" else fam_color, size=defsize)
for photo in photo_list:
    Soons_graph.add_node(photo, color=photo_color, size=defsize)

# Adding edges with weights
edges = [
    (family_mem[0], family_mem[1], {'weight': 6}),
    (family_mem[0], family_mem[2], {'weight': 6}),
    (family_mem[0], family_mem[3], {'weight': 8}),
    (family_mem[0], family_mem[4], {'weight': 8}),
    (family_mem[0], family_mem[5], {'weight': 3}),
    (family_mem[0], family_mem[6], {'weight': 4}),
    (family_mem[0], family_mem[7], {'weight': 3}),
    
    (family_mem[0], photo_list[0]),
    (family_mem[5], photo_list[0]),
    
    (family_mem[0], photo_list[1]),
    (family_mem[5], photo_list[1]), #maternal grandpa 
    
    (family_mem[1], photo_list[2]),
    (family_mem[0], photo_list[2]),
    (family_mem[3], photo_list[2]),
    (family_mem[2], photo_list[2]),
    
    (family_mem[2], photo_list[3]),
    (family_mem[4], photo_list[3]),
    (family_mem[0], photo_list[3]),
    (family_mem[5], photo_list[3]),
    
    (family_mem[2], photo_list[4]),
    (family_mem[4], photo_list[4]),
    (family_mem[0], photo_list[4]),
    (family_mem[5], photo_list[4]),
    
    (family_mem[2], photo_list[5]),
    (family_mem[0], photo_list[5]),

    (family_mem[0], photo_list[6]),
   
    (family_mem[3], photo_list[7]),
    (family_mem[0], photo_list[7]),

    (family_mem[0], photo_list[8]),
    (family_mem[3], photo_list[8]),
    
    (family_mem[5], photo_list[9]),
    (family_mem[3], photo_list[9]),
    (family_mem[1], photo_list[9]),
    (family_mem[0], photo_list[9]),

    (family_mem[4], photo_list[10]),
    (family_mem[1], photo_list[10]),
    (family_mem[3], photo_list[10]),
    (family_mem[0], photo_list[10]),
    (family_mem[2], photo_list[10]),

    (family_mem[5], photo_list[11]),
    (family_mem[0], photo_list[11]),

    (family_mem[0], photo_list[12]),
    
    (family_mem[4], photo_list[13]),

    (family_mem[0], photo_list[14]),
    (family_mem[3], photo_list[14]),
    (family_mem[1], photo_list[14]),
    (family_mem[4], photo_list[14]),

    (family_mem[3], photo_list[15]),
    (family_mem[2], photo_list[15]),
    (family_mem[0], photo_list[15]),

    (family_mem[3], photo_list[16]),
    (family_mem[0], photo_list[16]),
    (family_mem[2], photo_list[16]),

    (family_mem[3], photo_list[17]),
    (family_mem[0], photo_list[17]),
    (family_mem[1], photo_list[17]),

    (family_mem[1], photo_list[18]),
    (family_mem[3], photo_list[18]),
    (family_mem[2], photo_list[18]),
    (family_mem[0], photo_list[18]),
    (family_mem[5], photo_list[18]),

    (family_mem[1], photo_list[19]),
    (family_mem[3], photo_list[19]),
    (family_mem[6], photo_list[19]),
    (family_mem[0], photo_list[19]),
    (family_mem[5], photo_list[19]),

    (family_mem[1], photo_list[20]),
    (family_mem[7], photo_list[20]),
    (family_mem[6], photo_list[20]),
    (family_mem[0], photo_list[20]),
]
Soons_graph.add_edges_from(edges)

# Extract node attributes
node_colors = list(nx.get_node_attributes(Soons_graph, "color").values())
node_sizes = list(nx.get_node_attributes(Soons_graph, "size").values())
edge_labels = nx.get_edge_attributes(Soons_graph, 'weight')

# Initial spring layout
pos = nx.spring_layout(Soons_graph, k=0.5)

# Adjust positions to ensure family is closer to 'Soon' and photos are farther
for node in pos:
    if node == "Soon":
        pos[node] = (0, 0)  # Center

    elif node in family_mem:
        pos[node] = (pos[node][0] * 1.4, pos[node][1] * 1.4)
    
    elif node in photo_list:
        pos[node] = (pos[node][0] * 1.8, pos[node][1] * 1.8)  # Push farther

# Plot the graph
pos = nx.spring_layout(Soons_graph, k=0.3) # Increase k from the default 0.1
plt.figure(figsize=(12, 12))
nx.draw(Soons_graph, pos, with_labels=True, node_color=node_colors, node_size=node_sizes)
nx.draw_networkx_edge_labels(Soons_graph, pos, edge_labels=edge_labels)

plt.title("Soon's graph")
plt.show()

# %% [markdown]
# ### Graph Attention Network

# %% [markdown]
# source: https://mlabonne.github.io/blog/posts/2022-03-09-Graph_Attention_Network.html

# %%
import torch
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Numpy for matrices
import numpy as np
np.random.seed(0)
# Out:
# WARNING: Skipping /Users/belensaavedra/anaconda3/lib/python3.11/site-packages/mistune-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/belensaavedra/anaconda3/lib/python3.11/site-packages/mistune-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/belensaavedra/anaconda3/lib/python3.11/site-packages/mistune-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/belensaavedra/anaconda3/lib/python3.11/site-packages/mistune-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/belensaavedra/anaconda3/lib/python3.11/site-packages/mistune-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/belensaavedra/anaconda3/lib/python3.11/site-packages/mistune-0.8.4.dist-info due to invalid metadata entry 'name'

# %%
import torch.nn.functional as F
from torch.nn import Linear, Dropout
from torch_geometric.nn import GCNConv, GATv2Conv

class GAT(torch.nn.Module):
    """Graph Attention Network"""
    def __init__(self, dim_in, dim_h, dim_out, heads=8):
        super().__init__()
        self.gat1 = GATv2Conv(dim_in, dim_h, heads=heads)
        self.gat2 = GATv2Conv(dim_h*heads, dim_out, heads=1)
        self.optimizer = torch.optim.Adam(self.parameters(),
                                          lr=0.005,
                                          weight_decay=5e-4)

    def forward(self, x, edge_index):
        h = F.dropout(x, p=0.6, training=self.training)
        h = self.gat1(h, edge_index)
        h = F.elu(h)
        h = F.dropout(h, p=0.6, training=self.training)
        h = self.gat2(h, edge_index)
        return h, F.log_softmax(h, dim=1)

def accuracy(pred_y, y):
    """Calculate accuracy."""
    return ((pred_y == y).sum() / len(y)).item()

def train(model, data):
    """Train a GNN model and return the trained model."""
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = model.optimizer
    epochs = 200

    model.train()
    for epoch in range(epochs+1):
        # Training
        optimizer.zero_grad()
        _, out = model(data.x, data.edge_index)
        loss = criterion(out[data.train_mask], data.y[data.train_mask])
        acc = accuracy(out[data.train_mask].argmax(dim=1), data.y[data.train_mask])
        loss.backward()
        optimizer.step()

        # Validation
        val_loss = criterion(out[data.val_mask], data.y[data.val_mask])
        val_acc = accuracy(out[data.val_mask].argmax(dim=1), data.y[data.val_mask])

        # Print metrics every 10 epochs
        if(epoch % 10 == 0):
            print(f'Epoch {epoch:>3} | Train Loss: {loss:.3f} | Train Acc: '
                  f'{acc*100:>6.2f}% | Val Loss: {val_loss:.2f} | '
                  f'Val Acc: {val_acc*100:.2f}%')
          
    return model

@torch.no_grad()
def test(model, data):
    """Evaluate the model on test set and print the accuracy score."""
    model.eval()
    _, out = model(data.x, data.edge_index)
    acc = accuracy(out.argmax(dim=1)[data.test_mask], data.y[data.test_mask])
    return acc

# %%
import torch
from torch_geometric.utils import from_networkx

for u, v in Soons_graph.edges:
    if 'weight' not in Soons_graph[u][v]:  
        Soons_graph[u][v]['weight'] = 'n'  # Default weight for unweighted edges
        
soons_data = from_networkx(Soons_graph)

# Step 2: Add Node Features (One-hot encoding for simplicity)
num_nodes = soons_data.num_nodes
soons_data.x = torch.eye(num_nodes)

# Step 3: Create Random Masks for Train, Validation, and Test
soons_data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
soons_data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
soons_data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)

# Example: 60% train, 20% val, 20% test
train_size = int(0.6 * num_nodes)
val_size = int(0.2 * num_nodes)
test_size = num_nodes - train_size - val_size

soons_data.train_mask[:train_size] = 1
soons_data.val_mask[train_size:train_size + val_size] = 1
soons_data.test_mask[train_size + val_size:] = 1

# Step 4: Create Random Labels for Classification
soons_data.y = torch.randint(0, 2, (num_nodes,))  # Assuming a binary classification

# Step 5: Initialize and Train the GAT Model
model = GAT(dim_in=num_nodes, dim_h=16, dim_out=2)
trained_model = train(model, soons_data)

# Step 6: Test
test_acc = test(trained_model, soons_data)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch   0 | Train Loss: 0.678 | Train Acc:  70.59% | Val Loss: 0.65 | Val Acc: 80.00%
# Epoch  10 | Train Loss: 0.670 | Train Acc:  52.94% | Val Loss: 0.66 | Val Acc: 60.00%
# Epoch  20 | Train Loss: 0.636 | Train Acc:  64.71% | Val Loss: 0.68 | Val Acc: 80.00%
# Epoch  30 | Train Loss: 0.672 | Train Acc:  41.18% | Val Loss: 0.71 | Val Acc: 60.00%
# Epoch  40 | Train Loss: 0.611 | Train Acc:  64.71% | Val Loss: 0.76 | Val Acc: 60.00%
# Epoch  50 | Train Loss: 0.789 | Train Acc:  47.06% | Val Loss: 0.98 | Val Acc: 40.00%
# Epoch  60 | Train Loss: 0.468 | Train Acc:  76.47% | Val Loss: 0.53 | Val Acc: 80.00%
# Epoch  70 | Train Loss: 0.628 | Train Acc:  52.94% | Val Loss: 0.39 | Val Acc: 100.00%
# Epoch  80 | Train Loss: 0.595 | Train Acc:  52.94% | Val Loss: 0.70 | Val Acc: 60.00%
# Epoch  90 | Train Loss: 0.557 | Train Acc:  52.94% | Val Loss: 0.75 | Val Acc: 0.00%
# Epoch 100 | Train Loss: 0.595 | Train Acc:  64.71% | Val Loss: 0.71 | Val Acc: 40.00%
# ...

# %%
model.eval()
_, out = model(soons_data.x, soons_data.edge_index)

# %%
photo_indices = [i for i, node in enumerate(Soons_graph.nodes) if node in photo_list]
photo_predictions = out[photo_indices]
photo_scores = torch.softmax(photo_predictions, dim=1)[:, 1]  # Assuming 1 is the positive class
recommended_photos = sorted(zip(photo_list, photo_scores.tolist()), key=lambda x: x[1], reverse=True)
for photo, score in recommended_photos:
    print(f'{photo}: {score:.4f}')
# Out:
# photo6.png: 0.8099
# photo7.png: 0.7701
# photo21.png: 0.7554
# photo1.png: 0.7085
# photo5.png: 0.6659
# photo3.png: 0.5725
# photo20.png: 0.5364
# photo17.png: 0.4870
# photo16.png: 0.4870
# photo12.png: 0.4620
# photo19.png: 0.4417
# photo4.png: 0.4275
# photo13.png: 0.3997
# photo11.png: 0.3714
# photo2.png: 0.3194
# photo10.png: 0.3145
# photo18.png: 0.2368
# photo14.png: 0.2365
# photo15.png: 0.2256
# photo9.png: 0.1392
# photo8.png: 0.1337

# %% [markdown]
# ## Kefa's graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

Kefas_graph = nx.DiGraph()

user_color = "pink"
fam_color = "orange"
photo_color = "yellow"
defsize = 500

family_mem = ["Kefa", "Mother", "Brother1", "Brother2", "Sister", "Nephew", "Niece", "Sister-in-law", "Classmates", "Co-workers"]
photo_list = [f"photo{i}.png" for i in range(1, 13)]

# Adding nodes
for name in family_mem:
    Kefas_graph.add_node(name, color=user_color if name == "Kefa" else fam_color, size=defsize)
for photo in photo_list:
    Kefas_graph.add_node(photo, color=photo_color, size=defsize)

# Adding edges with weights
edges = [
    (family_mem[0], family_mem[1], {'weight': 9}),
    (family_mem[0], family_mem[2], {'weight': 8}),
    (family_mem[0], family_mem[3], {'weight': 5}),
    (family_mem[0], family_mem[4], {'weight': 6}),
    (family_mem[0], family_mem[5], {'weight': 2}),
    (family_mem[0], family_mem[6], {'weight': 4}),
    (family_mem[0], family_mem[7], {'weight': 1}),
    (family_mem[0], family_mem[7], {'weight': 7}),
    (family_mem[0], family_mem[7], {'weight': 2}),
    
    (family_mem[0], photo_list[0]),
    (family_mem[9], photo_list[0]),
    
    (family_mem[0], photo_list[1]),
    (family_mem[8], photo_list[1]), 
    
    (family_mem[3], photo_list[2]),
    (family_mem[7], photo_list[2]),
    (family_mem[5], photo_list[2]),

    #photo 4
    (family_mem[3], photo_list[3]),
    (family_mem[1], photo_list[3]),
    (family_mem[6], photo_list[3]),
    (family_mem[7], photo_list[3]),

    
    (family_mem[1], photo_list[4]),
    (family_mem[2], photo_list[4]),

    
    (family_mem[1], photo_list[5]),
    (family_mem[9], photo_list[5]),

    #photo 7
    (family_mem[0], photo_list[6]),

    
    (family_mem[0], photo_list[7]),
    (family_mem[3], photo_list[7]),
    (family_mem[2], photo_list[7]),
    (family_mem[1], photo_list[7]),

    
    (family_mem[0], photo_list[8]),
    (family_mem[4], photo_list[8]),

    
    (family_mem[0], photo_list[9]),
    (family_mem[8], photo_list[9]),
  

    (family_mem[0], photo_list[10]),
   
    (family_mem[4], photo_list[11]),
    (family_mem[2], photo_list[11])
]
Kefas_graph.add_edges_from(edges)

# Extract node attributes
node_colors = list(nx.get_node_attributes(Kefas_graph, "color").values())
node_sizes = list(nx.get_node_attributes(Kefas_graph, "size").values())
edge_labels = nx.get_edge_attributes(Kefas_graph, 'weight')

# Initial spring layout
pos = nx.spring_layout(Kefas_graph, k=0.5)

# Adjust positions to ensure family is closer to 'Soon' and photos are farther
for node in pos:
    if node == "Kefa":
        pos[node] = (0, 0)  # Center
    if node == "Mother":
        pos[node] = (0, 50)
    if node == "Brother1":
        pos[node]= (50, 0)
    
# Plot the graph
pos = nx.spring_layout(Kefas_graph, k=0.3) # Increase k from the default 0.1
plt.figure(figsize=(12, 12))
nx.draw(Kefas_graph, pos, with_labels=True, node_color=node_colors, node_size=node_sizes)
nx.draw_networkx_edge_labels(Kefas_graph, pos, edge_labels=edge_labels)
plt.title("Soon's dad")
plt.show()

# %% [markdown]
# ## Network

# %%
# %%time
# Create GCN model
gcn = GCN(dataset.num_features, 16, dataset.num_classes)
print(gcn)

# Train and test
train(gcn, data)
acc = test(gcn, data)
print(f'\nGCN test accuracy: {acc*100:.2f}%\n')
